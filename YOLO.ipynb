# %%
# !pip install --upgrade ultralytics
from ultralytics import YOLO

# %%
data_config_path=r"/content/drive/MyDrive/Classroom/car-20240713T201518Z-001/car/data.yaml"

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data=data_config_path, epochs=2, imgsz=640, batch=32)
# Out:
# Ultralytics YOLOv8.2.56 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model.val(data=data_config_path)
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,008,768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Classroom/car-20240713T201518Z-001/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100%|██████████| 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:52<00:00, 10.48s/it]
#                    all        160       1055      0.471      0.325      0.402       0.26
#                   boot         35         39          0          0      0.151     0.0972
#                    car        142        145      0.748      0.972      0.941      0.734
#                   door         50         52      0.519      0.365      0.418      0.198
#           front_bumper         30         30      0.139      0.267       0.21       0.12
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the confusion matrix
confusion_matrix_path = '/content/runs/detect/train/confusion_matrix.png'
img = mpimg.imread(confusion_matrix_path)
imgplot = plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
from ultralytics import YOLO

# Assuming 'results' is the output of your validation run
results = model.val(data=data_config_path)
# Out:
# Ultralytics YOLOv8.2.56 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# val: Scanning /content/drive/MyDrive/Classroom/car-20240713T201518Z-001/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100%|██████████| 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:49<00:00,  9.91s/it]
#                    all        160       1055      0.471      0.325      0.402       0.26
#                   boot         35         39          0          0      0.151     0.0972
#                    car        142        145      0.748      0.972      0.941      0.734
#                   door         50         52      0.519      0.365      0.418      0.198
#           front_bumper         30         30      0.139      0.267       0.21       0.12
#            front_grill         49         51      0.405      0.216      0.262      0.154
# ...

# %%
model.plot_confusion_matrix(save_dir='/content/runs/detect/train63')
model.plot_results(save_dir='/content/runs/detect/train63')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3012bf26ec12> in <cell line: 1>()
# ----> 1 model.plot_confusion_matrix(save_dir='/content/runs/detect/train63')
#       2 model.plot_results(save_dir='/content/runs/detect/train63')
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1707             if name in modules:
#    1708                 return modules[name]
# -> 1709         raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#    1710
#    1711     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'YOLO' object has no attribute 'plot_confusion_matrix'
